# %% [markdown]
# <a href="https://colab.research.google.com/github/Aishwarya327/NNDL_LAB/blob/main/ANN_XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras==2.8
# Out:
# Requirement already satisfied: keras==2.8 in /usr/local/lib/python3.7/dist-packages (2.8.0)

# %%
pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (4.1.1)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 4.9 MB/s
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.23.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Installing collected packages: tf-estimator-nightly
# Successfully installed tf-estimator-nightly-2.8.0.dev2021122109

# %%
pip install --upgrade tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.8.0-cp37-cp37m-manylinux2010_x86_64.whl (497.5 MB)
#      |████████████████████████████████| 497.5 MB 22 kB/s
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.5.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.17.3)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.8.0.dev2021122109)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.44.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.23.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.2.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.8.0

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# %%
training_data = np.array([[0,0],[0,1],[1,0],[1,1]])

# %%
target_data = np.array([[0],[1],[1],[0]])

# %%
model= Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['binary_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                48
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 65
# Trainable params: 65
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(training_data, target_data, epochs=250, verbose=2)
# Out:
# Epoch 1/250
# 1/1 - 0s - loss: 0.2367 - binary_accuracy: 1.0000 - 421ms/epoch - 421ms/step
# Epoch 2/250
# 1/1 - 0s - loss: 0.2364 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 3/250
# 1/1 - 0s - loss: 0.2359 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 4/250
# 1/1 - 0s - loss: 0.2355 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 5/250
# 1/1 - 0s - loss: 0.2352 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 6/250
# 1/1 - 0s - loss: 0.2348 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 7/250
# 1/1 - 0s - loss: 0.2344 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 8/250
# 1/1 - 0s - loss: 0.2341 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 9/250
# 1/1 - 0s - loss: 0.2337 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 10/250
# 1/1 - 0s - loss: 0.2334 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 11/250
# 1/1 - 0s - loss: 0.2330 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 12/250
# 1/1 - 0s - loss: 0.2326 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 13/250
# 1/1 - 0s - loss: 0.2323 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 14/250
# 1/1 - 0s - loss: 0.2320 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 15/250
# 1/1 - 0s - loss: 0.2317 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 16/250
# 1/1 - 0s - loss: 0.2314 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 17/250
# 1/1 - 0s - loss: 0.2312 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 18/250
# 1/1 - 0s - loss: 0.2309 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 19/250
# 1/1 - 0s - loss: 0.2306 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 20/250
# 1/1 - 0s - loss: 0.2303 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 21/250
# 1/1 - 0s - loss: 0.2301 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 22/250
# 1/1 - 0s - loss: 0.2298 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 23/250
# 1/1 - 0s - loss: 0.2295 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 24/250
# 1/1 - 0s - loss: 0.2292 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 25/250
# 1/1 - 0s - loss: 0.2290 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 26/250
# 1/1 - 0s - loss: 0.2287 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 27/250
# 1/1 - 0s - loss: 0.2284 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 28/250
# 1/1 - 0s - loss: 0.2282 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 29/250
# 1/1 - 0s - loss: 0.2279 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 30/250
# 1/1 - 0s - loss: 0.2276 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 31/250
# 1/1 - 0s - loss: 0.2274 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 32/250
# 1/1 - 0s - loss: 0.2271 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 33/250
# 1/1 - 0s - loss: 0.2268 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 34/250
# 1/1 - 0s - loss: 0.2266 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 35/250
# 1/1 - 0s - loss: 0.2263 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 36/250
# 1/1 - 0s - loss: 0.2260 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 37/250
# 1/1 - 0s - loss: 0.2258 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 38/250
# 1/1 - 0s - loss: 0.2255 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 39/250
# 1/1 - 0s - loss: 0.2253 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 40/250
# 1/1 - 0s - loss: 0.2250 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 41/250
# 1/1 - 0s - loss: 0.2247 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 42/250
# 1/1 - 0s - loss: 0.2245 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 43/250
# 1/1 - 0s - loss: 0.2242 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 44/250
# 1/1 - 0s - loss: 0.2240 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 45/250
# 1/1 - 0s - loss: 0.2237 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 46/250
# 1/1 - 0s - loss: 0.2234 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 47/250
# 1/1 - 0s - loss: 0.2232 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 48/250
# 1/1 - 0s - loss: 0.2229 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 49/250
# 1/1 - 0s - loss: 0.2227 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 50/250
# 1/1 - 0s - loss: 0.2224 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 51/250
# 1/1 - 0s - loss: 0.2221 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 52/250
# 1/1 - 0s - loss: 0.2219 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 53/250
# 1/1 - 0s - loss: 0.2216 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 54/250
# 1/1 - 0s - loss: 0.2214 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 55/250
# 1/1 - 0s - loss: 0.2212 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 56/250
# 1/1 - 0s - loss: 0.2209 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 57/250
# 1/1 - 0s - loss: 0.2207 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 58/250
# 1/1 - 0s - loss: 0.2205 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 59/250
# 1/1 - 0s - loss: 0.2202 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 60/250
# 1/1 - 0s - loss: 0.2200 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 61/250
# 1/1 - 0s - loss: 0.2198 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 62/250
# 1/1 - 0s - loss: 0.2195 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 63/250
# 1/1 - 0s - loss: 0.2193 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 64/250
# 1/1 - 0s - loss: 0.2190 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 65/250
# 1/1 - 0s - loss: 0.2188 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 66/250
# 1/1 - 0s - loss: 0.2186 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 67/250
# 1/1 - 0s - loss: 0.2183 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 68/250
# 1/1 - 0s - loss: 0.2181 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 69/250
# 1/1 - 0s - loss: 0.2178 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 70/250
# 1/1 - 0s - loss: 0.2176 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 71/250
# 1/1 - 0s - loss: 0.2173 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 72/250
# 1/1 - 0s - loss: 0.2171 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 73/250
# 1/1 - 0s - loss: 0.2168 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 74/250
# 1/1 - 0s - loss: 0.2166 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 75/250
# 1/1 - 0s - loss: 0.2163 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 76/250
# 1/1 - 0s - loss: 0.2161 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 77/250
# 1/1 - 0s - loss: 0.2158 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 78/250
# 1/1 - 0s - loss: 0.2156 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 79/250
# 1/1 - 0s - loss: 0.2153 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 80/250
# 1/1 - 0s - loss: 0.2151 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 81/250
# 1/1 - 0s - loss: 0.2148 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 82/250
# 1/1 - 0s - loss: 0.2146 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 83/250
# 1/1 - 0s - loss: 0.2143 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 84/250
# 1/1 - 0s - loss: 0.2141 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 85/250
# 1/1 - 0s - loss: 0.2138 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 86/250
# 1/1 - 0s - loss: 0.2135 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 87/250
# 1/1 - 0s - loss: 0.2133 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 88/250
# 1/1 - 0s - loss: 0.2130 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 89/250
# 1/1 - 0s - loss: 0.2128 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 90/250
# 1/1 - 0s - loss: 0.2125 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 91/250
# 1/1 - 0s - loss: 0.2122 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 92/250
# 1/1 - 0s - loss: 0.2120 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 93/250
# 1/1 - 0s - loss: 0.2117 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 94/250
# 1/1 - 0s - loss: 0.2114 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 95/250
# 1/1 - 0s - loss: 0.2112 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 96/250
# 1/1 - 0s - loss: 0.2109 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 97/250
# 1/1 - 0s - loss: 0.2107 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 98/250
# 1/1 - 0s - loss: 0.2104 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 99/250
# 1/1 - 0s - loss: 0.2101 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 100/250
# 1/1 - 0s - loss: 0.2098 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 101/250
# 1/1 - 0s - loss: 0.2096 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 102/250
# 1/1 - 0s - loss: 0.2093 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 103/250
# 1/1 - 0s - loss: 0.2090 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 104/250
# 1/1 - 0s - loss: 0.2088 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 105/250
# 1/1 - 0s - loss: 0.2085 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 106/250
# 1/1 - 0s - loss: 0.2082 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 107/250
# 1/1 - 0s - loss: 0.2079 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 108/250
# 1/1 - 0s - loss: 0.2077 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 109/250
# 1/1 - 0s - loss: 0.2074 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 110/250
# 1/1 - 0s - loss: 0.2071 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 111/250
# 1/1 - 0s - loss: 0.2069 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 112/250
# 1/1 - 0s - loss: 0.2066 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 113/250
# 1/1 - 0s - loss: 0.2063 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 114/250
# 1/1 - 0s - loss: 0.2060 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 115/250
# 1/1 - 0s - loss: 0.2058 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 116/250
# 1/1 - 0s - loss: 0.2055 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 117/250
# 1/1 - 0s - loss: 0.2052 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 118/250
# 1/1 - 0s - loss: 0.2049 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 119/250
# 1/1 - 0s - loss: 0.2046 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 120/250
# 1/1 - 0s - loss: 0.2044 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 121/250
# 1/1 - 0s - loss: 0.2041 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 122/250
# 1/1 - 0s - loss: 0.2038 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 123/250
# 1/1 - 0s - loss: 0.2035 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 124/250
# 1/1 - 0s - loss: 0.2032 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 125/250
# 1/1 - 0s - loss: 0.2030 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 126/250
# 1/1 - 0s - loss: 0.2027 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 127/250
# 1/1 - 0s - loss: 0.2024 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 128/250
# 1/1 - 0s - loss: 0.2021 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 129/250
# 1/1 - 0s - loss: 0.2018 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 130/250
# 1/1 - 0s - loss: 0.2015 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 131/250
# 1/1 - 0s - loss: 0.2012 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 132/250
# 1/1 - 0s - loss: 0.2010 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 133/250
# 1/1 - 0s - loss: 0.2007 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 134/250
# 1/1 - 0s - loss: 0.2004 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 135/250
# 1/1 - 0s - loss: 0.2001 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 136/250
# 1/1 - 0s - loss: 0.1998 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 137/250
# 1/1 - 0s - loss: 0.1995 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 138/250
# 1/1 - 0s - loss: 0.1992 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 139/250
# 1/1 - 0s - loss: 0.1989 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 140/250
# 1/1 - 0s - loss: 0.1986 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 141/250
# 1/1 - 0s - loss: 0.1983 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 142/250
# 1/1 - 0s - loss: 0.1980 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 143/250
# 1/1 - 0s - loss: 0.1977 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 144/250
# 1/1 - 0s - loss: 0.1974 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 145/250
# 1/1 - 0s - loss: 0.1971 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 146/250
# 1/1 - 0s - loss: 0.1968 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 147/250
# 1/1 - 0s - loss: 0.1965 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 148/250
# 1/1 - 0s - loss: 0.1962 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 149/250
# 1/1 - 0s - loss: 0.1959 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 150/250
# 1/1 - 0s - loss: 0.1956 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 151/250
# 1/1 - 0s - loss: 0.1953 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 152/250
# 1/1 - 0s - loss: 0.1950 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 153/250
# 1/1 - 0s - loss: 0.1947 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 154/250
# 1/1 - 0s - loss: 0.1944 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 155/250
# 1/1 - 0s - loss: 0.1941 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 156/250
# 1/1 - 0s - loss: 0.1938 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 157/250
# 1/1 - 0s - loss: 0.1935 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 158/250
# 1/1 - 0s - loss: 0.1932 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 159/250
# 1/1 - 0s - loss: 0.1929 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 160/250
# 1/1 - 0s - loss: 0.1926 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 161/250
# 1/1 - 0s - loss: 0.1923 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 162/250
# 1/1 - 0s - loss: 0.1920 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 163/250
# 1/1 - 0s - loss: 0.1917 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 164/250
# 1/1 - 0s - loss: 0.1914 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 165/250
# 1/1 - 0s - loss: 0.1911 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 166/250
# 1/1 - 0s - loss: 0.1907 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 167/250
# 1/1 - 0s - loss: 0.1904 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 168/250
# 1/1 - 0s - loss: 0.1901 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 169/250
# 1/1 - 0s - loss: 0.1898 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 170/250
# 1/1 - 0s - loss: 0.1895 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 171/250
# 1/1 - 0s - loss: 0.1892 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 172/250
# 1/1 - 0s - loss: 0.1889 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 173/250
# 1/1 - 0s - loss: 0.1886 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 174/250
# 1/1 - 0s - loss: 0.1883 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 175/250
# 1/1 - 0s - loss: 0.1880 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 176/250
# 1/1 - 0s - loss: 0.1877 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 177/250
# 1/1 - 0s - loss: 0.1873 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 178/250
# 1/1 - 0s - loss: 0.1870 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 179/250
# 1/1 - 0s - loss: 0.1867 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 180/250
# 1/1 - 0s - loss: 0.1864 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 181/250
# 1/1 - 0s - loss: 0.1861 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 182/250
# 1/1 - 0s - loss: 0.1858 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 183/250
# 1/1 - 0s - loss: 0.1855 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 184/250
# 1/1 - 0s - loss: 0.1852 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 185/250
# 1/1 - 0s - loss: 0.1849 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 186/250
# 1/1 - 0s - loss: 0.1845 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 187/250
# 1/1 - 0s - loss: 0.1842 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 188/250
# 1/1 - 0s - loss: 0.1839 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 189/250
# 1/1 - 0s - loss: 0.1836 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 190/250
# 1/1 - 0s - loss: 0.1833 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 191/250
# 1/1 - 0s - loss: 0.1830 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 192/250
# 1/1 - 0s - loss: 0.1827 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 193/250
# 1/1 - 0s - loss: 0.1824 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 194/250
# 1/1 - 0s - loss: 0.1821 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 195/250
# 1/1 - 0s - loss: 0.1818 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 196/250
# 1/1 - 0s - loss: 0.1815 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 197/250
# 1/1 - 0s - loss: 0.1811 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 198/250
# 1/1 - 0s - loss: 0.1808 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 199/250
# 1/1 - 0s - loss: 0.1805 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 200/250
# 1/1 - 0s - loss: 0.1802 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 201/250
# 1/1 - 0s - loss: 0.1799 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 202/250
# 1/1 - 0s - loss: 0.1796 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 203/250
# 1/1 - 0s - loss: 0.1793 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 204/250
# 1/1 - 0s - loss: 0.1789 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 205/250
# 1/1 - 0s - loss: 0.1786 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 206/250
# 1/1 - 0s - loss: 0.1783 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 207/250
# 1/1 - 0s - loss: 0.1780 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 208/250
# 1/1 - 0s - loss: 0.1777 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 209/250
# 1/1 - 0s - loss: 0.1774 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 210/250
# 1/1 - 0s - loss: 0.1771 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 211/250
# 1/1 - 0s - loss: 0.1767 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 212/250
# 1/1 - 0s - loss: 0.1764 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 213/250
# 1/1 - 0s - loss: 0.1761 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 214/250
# 1/1 - 0s - loss: 0.1758 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 215/250
# 1/1 - 0s - loss: 0.1755 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 216/250
# 1/1 - 0s - loss: 0.1751 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 217/250
# 1/1 - 0s - loss: 0.1748 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 218/250
# 1/1 - 0s - loss: 0.1745 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 219/250
# 1/1 - 0s - loss: 0.1742 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 220/250
# 1/1 - 0s - loss: 0.1739 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 221/250
# 1/1 - 0s - loss: 0.1735 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 222/250
# 1/1 - 0s - loss: 0.1732 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 223/250
# 1/1 - 0s - loss: 0.1729 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 224/250
# 1/1 - 0s - loss: 0.1726 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 225/250
# 1/1 - 0s - loss: 0.1723 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 226/250
# 1/1 - 0s - loss: 0.1719 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 227/250
# 1/1 - 0s - loss: 0.1716 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 228/250
# 1/1 - 0s - loss: 0.1713 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 229/250
# 1/1 - 0s - loss: 0.1710 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 230/250
# 1/1 - 0s - loss: 0.1706 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 231/250
# 1/1 - 0s - loss: 0.1703 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 232/250
# 1/1 - 0s - loss: 0.1700 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 233/250
# 1/1 - 0s - loss: 0.1697 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 234/250
# 1/1 - 0s - loss: 0.1694 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 235/250
# 1/1 - 0s - loss: 0.1691 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 236/250
# 1/1 - 0s - loss: 0.1687 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 237/250
# 1/1 - 0s - loss: 0.1684 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 238/250
# 1/1 - 0s - loss: 0.1681 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 239/250
# 1/1 - 0s - loss: 0.1677 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 240/250
# 1/1 - 0s - loss: 0.1674 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 241/250
# 1/1 - 0s - loss: 0.1671 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 242/250
# 1/1 - 0s - loss: 0.1668 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 243/250
# 1/1 - 0s - loss: 0.1664 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 244/250
# 1/1 - 0s - loss: 0.1661 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 245/250
# 1/1 - 0s - loss: 0.1658 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 246/250
# 1/1 - 0s - loss: 0.1655 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 247/250
# 1/1 - 0s - loss: 0.1651 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 248/250
# 1/1 - 0s - loss: 0.1648 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 249/250
# 1/1 - 0s - loss: 0.1645 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 250/250
# 1/1 - 0s - loss: 0.1642 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step

# %%
print(model.predict(training_data).round())
# Out:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
